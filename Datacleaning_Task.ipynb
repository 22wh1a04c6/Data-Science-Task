# %% [markdown]
# <a href="https://colab.research.google.com/github/22wh1a04c6/Data-Science-Task/blob/main/Datacleaning_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data cleaning task

# %%
# data cleaning task
df=pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Cleaning/laptopData.csv")

# %%
# handling null values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# remove unnamed col
df=df.drop("Unnamed: 0",axis=1)
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
#drop duplicate rows
df.drop_duplicates(inplace=True)
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1269    Asus            Notebook   15.6
# 1270  Lenovo  2 in 1 Convertible     14
# 1271  Lenovo  2 in 1 Convertible   13.3
# 1272  Lenovo            Notebook     14
# 1273      HP            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
# handling inches column
df["Inches"]=df["Inches"].replace("?","0")
df["Inches"]=df["Inches"].astype(float)
avg_inch=round(df["Inches"].mean())
df["Inches"]=df["Inches"].replace(0,avg_inch)
df
df["Inches"].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 17.3, 13.5, 12.5, 13. , 18.4, 13.9,
#        11.6, 25.6, 35.6, 12.3, 27.3, 24. , 33.5, 15. , 31.6, 17. , 14.1,
#        11.3, 10.1])

# %%
# handling memory column
df["Memory"].mode()
df["Memory"]=df["Memory"].replace("?","256GB SSD")
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
#handling weight column
df["Weight"]=df["Weight"].str.strip("kg")
df["Weight"]=df["Weight"].replace("?","0")
df["Weight"]=df["Weight"].astype(float)
avg_weight=round(df["Weight"].mean())
df["Weight"]=df["Weight"].replace(0,avg_weight)

df["Weight"].unique()
# Out:
# array([1.370e+00, 1.340e+00, 1.860e+00, 1.830e+00, 2.100e+00, 2.040e+00,
#        1.300e+00, 1.600e+00, 2.200e+00, 9.200e-01, 1.220e+00, 2.500e+00,
#        1.620e+00, 1.910e+00, 2.300e+00, 1.350e+00, 1.880e+00, 1.890e+00,
#        1.650e+00, 2.710e+00, 1.200e+00, 1.440e+00, 2.800e+00, 2.000e+00,
#        2.650e+00, 2.770e+00, 3.200e+00, 1.490e+00, 2.400e+00, 2.130e+00,
#        2.430e+00, 1.700e+00, 1.400e+00, 1.800e+00, 1.900e+00, 3.000e+00,
#        1.252e+00, 2.700e+00, 2.020e+00, 1.630e+00, 1.960e+00, 1.210e+00,
#        2.450e+00, 1.250e+00, 1.500e+00, 2.620e+00, 1.380e+00, 1.580e+00,
#        1.850e+00, 1.230e+00, 2.160e+00, 2.360e+00, 7.200e+00, 2.050e+00,
#        1.320e+00, 1.750e+00, 9.700e-01, 2.560e+00, 1.480e+00, 1.740e+00,
#        1.100e+00, 1.560e+00, 2.030e+00, 1.050e+00, 5.400e+00, 4.400e+00,
#        1.290e+00, 1.950e+00, 2.060e+00, 1.120e+00, 3.490e+00, 3.350e+00,
#        2.230e+00, 2.900e+00, 4.420e+00, 2.690e+00, 2.370e+00, 4.700e+00,
# ...

# %%
df.reset_index(inplace=True)
df=df.drop("index",axis=1)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1239    Asus            Notebook    15.6
# 1240  Lenovo  2 in 1 Convertible    14.0
# 1241  Lenovo  2 in 1 Convertible    13.3
# 1242  Lenovo            Notebook    14.0
# 1243      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1239                                    1366x768
# 1240   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
#kaggle task
df=pd.read_csv("Whatsapp_chat.csv")
df=df.drop("Unnamed: 0",axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-415/1984119832.py in <cell line: 0>()
#       1 #kaggle task
# ----> 2 df=pd.read_csv("Whatsapp_chat.csv")
#       3 df=df.drop("Unnamed: 0",axis=1)
#       4 df
#
# ...

# %%
df["timestamp"].unique()

# %%
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True)
df=df.drop("index",axis=1)
df

# %%
df=pd.read_csv("swiggy.csv")
df

# %%
df.shape
df.drop_duplicates(inplace=True)
df.shape

# %%
#datacleaning hw task
df=pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Cleaning/USA_presidents.csv")
df=df.drop("Unnamed: 0",axis=1)
df=df.drop("Unnamed: 0.1",axis=1)
df=df.drop("S.No.",axis=1)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df.reset_index(inplace=True)
df=df.drop("index",axis=1)
df
# Out:
#                  president                                              prior  \
# 0        John Quincy Adams  8th  United States Secretary of State   (1817â...
# 1           Andrew Jackson  U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 2         Martin Van Buren           8th  Vice President of the United States
# 3   William Henry Harrison  United States Minister to Colombia   (1828â€“1...
# 4               john tyler          10th  Vice President of the United States
# 5            James K. Polk         9th  Governor of Tennessee   (1839â€“1841)
# 6           Zachary Taylor  Major General  of the  1st Infantry Regiment  ...
# 7         Millard Fillmore          12th  Vice President of the United States
# 8          Franklin Pierce  Brigadier General  of the  9th Infantry   Unit...
# 9           James Buchanan  United States Minister  to the   Court of St J...
# 10         Abraham Lincoln  U.S. Representative  for  Illinois' 7th Distri...
# ...

# %%
df["date created"].unique()
# Out:
# array(['2012-03-04', '2020-02-01'], dtype=object)
